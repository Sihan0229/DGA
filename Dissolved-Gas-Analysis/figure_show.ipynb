# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 构造数据
data = {
    '特征': [
        '关键气体法', '关键气体法',
        'IEC三比值法', 'IEC三比值法',
        'Roger比值法', 'Roger比值法',
        'Duval三角法', 'Duval三角法'
    ],
    '模型': [
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr'
    ],
    'Accuracy': [0.8875, 0.8875, 0.8938, 0.8875, 0.9, 0.89375, 0.88125, 0.8875],
    'Recall': [0.8875, 0.8875, 0.8938, 0.8875, 0.9, 0.89375, 0.88125, 0.8875],
    'F1 Score': [0.8904, 0.8901, 0.8939, 0.8883, 0.9004, 0.8938, 0.8814, 0.8882],
    'Precision': [0.8968, 0.8957, 0.8988, 0.8931, 0.9049, 0.8968, 0.8897, 0.8946]
}

df = pd.DataFrame(data)

# 将长表格格式转换为适合 seaborn 的格式
df_melted = df.melt(id_vars=['特征', '模型'], 
                    value_vars=['Accuracy', 'Recall', 'F1 Score', 'Precision'],
                    var_name='评估指标', value_name='得分')

# 设置可视化风格
sns.set(style="whitegrid")

# 创建图
plt.figure(figsize=(14, 8))
chart = sns.barplot(
    x='特征', y='得分', hue='评估指标',
    data=df_melted, ci=None, palette='Set2',
    hue_order=['Accuracy', 'Recall', 'F1 Score', 'Precision']
)

# 为每个柱添加模型标签
for container in chart.containers:
    chart.bar_label(container, fmt='%.3f', label_type='edge', fontsize=8, padding=2)

plt.title('各方法在不同特征提取方式下的模型评估指标比较', fontsize=16)
plt.xlabel('特征提取方法', fontsize=12)
plt.ylabel('得分', fontsize=12)
plt.ylim(0.85, 0.91)
plt.legend(title='评估指标')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\1874035400.py:37: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   chart = sns.barplot(
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\1874035400.py:52: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\1874035400.py:52: UserWarning: Glyph 38190 (\N{CJK UNIFIED IDEOGRAPH-952E}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\1874035400.py:52: UserWarning: Glyph 27668 (\N{CJK UNIFIED IDEOGRAPH-6C14}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\1874035400.py:52: UserWarning: Glyph 20307 (\N{CJK UNIFIED IDEOGRAPH-4F53}) missing from font(s) Arial.
#   plt.tight_layout()
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=18)  # 中文宋体
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=18)   # Times New Roman

# 构造数据
data = {
    '特征': [
        '关键气体法', '关键气体法',
        'IEC三比值法', 'IEC三比值法',
        'Roger比值法', 'Roger比值法',
        'Duval三角法', 'Duval三角法'
    ],
    '模型': [
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr'
    ],
    'Accuracy': [0.8875, 0.8875, 0.8938, 0.8875, 0.9, 0.89375, 0.88125, 0.8875],
    'Recall': [0.8875, 0.8875, 0.8938, 0.8875, 0.9, 0.89375, 0.88125, 0.8875],
    'F1 Score': [0.8904, 0.8901, 0.8939, 0.8883, 0.9004, 0.8938, 0.8814, 0.8882],
    'Precision': [0.8968, 0.8957, 0.8988, 0.8931, 0.9049, 0.8968, 0.8897, 0.8946]
}

df = pd.DataFrame(data)

# 转换为适合 seaborn 的长格式
df_melted = df.melt(id_vars=['特征', '模型'], 
                    value_vars=['Accuracy', 'Recall', 'F1 Score', 'Precision'],
                    var_name='评估指标', value_name='得分')

# 设置风格
sns.set(style="whitegrid")

# 绘图
plt.figure(figsize=(16, 6))
chart = sns.barplot(
    x='特征', y='得分', hue='评估指标',
    data=df_melted, ci=None, palette='Set2',
    hue_order=['Accuracy', 'Recall', 'F1 Score', 'Precision']
)

# 添加数值标签
for container in chart.containers:
    chart.bar_label(container, fmt='%.3f', label_type='edge', fontsize=18, padding=2, fontproperties=font_en)

# 设置标题和标签（中文）
# plt.title('各方法在不同特征提取方式下的模型评估指标比较', fontsize=18, fontproperties=font_cn)
plt.xlabel('特征', fontsize=18, fontproperties=font_cn)
plt.ylabel('得分', fontsize=18, fontproperties=font_cn)
plt.ylim(0.88, 0.905)

# 设置图例字体
legend = plt.legend(title='评估指标', prop=font_en)
legend.get_title().set_fontproperties(font_cn)

plt.xticks(fontproperties=font_cn)
plt.yticks(fontproperties=font_en)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\570735487.py:42: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   chart = sns.barplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=20)  # 中文宋体
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=20)   # Times New Roman

# 构造数据
data = {
    '特征': [
        'Key Gas Gini', 'Key Gas Entr',
        'IEC Gini', 'IEC Entr',
        'Roger Gini', 'Roger Entr',
        'Duval Gini', 'Duval Entr'
    ],
    '模型': [
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr'
    ],
    'Accuracy': [0.8875,0.8875 ,0.8938,0.8875,0.875,0.88125,0.9,0.8875],
    'Recall': [0.8875,0.8875 ,0.8938,0.8875,0.875,0.88125,0.9,0.8875],
    'F1 Score': [0.8904 ,0.8901 ,0.8939,0.8883,0.8790,0.8835,0.9018,0.8896],
    'Precision': [0.8968 ,0.8957 ,0.8988,0.8931,0.8885,0.8881,0.9066,0.8963]
}

df = pd.DataFrame(data)

# 转换为适合 seaborn 的长格式
df_melted = df.melt(id_vars=['特征', '模型'], 
                    value_vars=['Accuracy', 'Recall', 'F1 Score', 'Precision'],
                    var_name='评估指标', value_name='得分')

# 计算同一评估指标下，每个特征的平均值
df_avg = df_melted.groupby(['特征', '评估指标'])['得分'].mean().reset_index()

# 设置风格
sns.set(style="whitegrid")

# 绘图
plt.figure(figsize=(16, 6))
chart = sns.barplot(
    x='评估指标', y='得分', hue='特征',
    data=df_avg, ci=None, palette='Set2'
)

# 添加数值标签
for container in chart.containers:
    chart.bar_label(container, fmt='%.3f', label_type='edge', fontsize=16, padding=2, fontproperties=font_en)

# 设置标题和标签（中文）
# plt.title('不同特征方法下的评估指标平均表现', fontsize=18, fontproperties=font_cn)
plt.xlabel('评估指标', fontsize=20, fontproperties=font_cn)
plt.ylabel('平均得分', fontsize=20, fontproperties=font_cn)
plt.ylim(0.88, 0.92)

# 设置图例字体和横向排列
legend = plt.legend(prop=font_en, ncol=4, loc='upper right')
legend.get_title().set_fontproperties(font_cn)


plt.xticks(fontproperties=font_en)
plt.yticks(fontproperties=font_en)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\1409520976.py:45: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   chart = sns.barplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=20)  # 中文宋体
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=20)   # Times New Roman

# 构造数据
data = {
    '特征': [
        'Key Gas Gini', 'Key Gas Entr',
        'IEC Gini', 'IEC Entr',
        'Roger Gini', 'Roger Entr',
        'Duval Gini', 'Duval Entr'
    ],
    '模型': [
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr',
        'RandomForestGini', 'RandomForestEntr'
    ],
    'Accuracy': [0.8875 ,0.8938 ,0.8938,0.8875,0.9,0.89375,0.88125,0.8875],
    'Recall': [0.8875 ,0.8938 ,0.8938,0.8875,0.9,0.89375,0.88125,0.8875],
    'F1 Score': [0.8883 ,0.8947 ,0.8939,0.8883,0.9004,0.8938,0.8814,0.8882],
    'Precision': [0.8931 ,0.8995 ,0.8988,0.8931,0.9049,0.8968,0.8897,0.8946]
}

df = pd.DataFrame(data)

# 转换为适合 seaborn 的长格式
df_melted = df.melt(id_vars=['特征', '模型'], 
                    value_vars=['Accuracy', 'Recall', 'F1 Score', 'Precision'],
                    var_name='评估指标', value_name='得分')

# 计算同一评估指标下，每个特征的平均值
df_avg = df_melted.groupby(['特征', '评估指标'])['得分'].mean().reset_index()

# 设置风格
sns.set(style="whitegrid")

# 绘图
plt.figure(figsize=(16, 6))
chart = sns.barplot(
    x='评估指标', y='得分', hue='特征',
    data=df_avg, ci=None, palette='Set2'
)

# 添加数值标签
for container in chart.containers:
    chart.bar_label(container, fmt='%.3f', label_type='edge', fontsize=16, padding=2, fontproperties=font_en)

# 设置标题和标签（中文）
# plt.title('不同特征方法下的评估指标平均表现', fontsize=18, fontproperties=font_cn)
plt.xlabel('评估指标', fontsize=20, fontproperties=font_cn)
plt.ylabel('平均得分', fontsize=20, fontproperties=font_cn)
plt.ylim(0.88, 0.92)

# 设置图例字体和横向排列
legend = plt.legend(prop=font_en, ncol=4, loc='upper right')
legend.get_title().set_fontproperties(font_cn)


plt.xticks(fontproperties=font_en)
plt.yticks(fontproperties=font_en)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\3042494082.py:45: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   chart = sns.barplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=20)  # 中文宋体
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=20)   # Times New Roman

# 构造数据
data = {
    '特征': [
        'Key Gas XGBoost', 'Key Gas LightGBM','Key Gas LightGBMXT',
        'IEC XGBoost', 'IEC LightGBM', 'IEC LightGBMXT',
        'Roger XGBoost', 'Roger LightGBM','Roger LightGBMXT',
        'Duval XGBoost', 'Duval LightGBM','Duval LightGBMXT'
    ],
    '模型': [
        'XGBoost', 'LightGBM','LightGBMXT',
        'XGBoost', 'LightGBM','LightGBMXT',
        'XGBoost', 'LightGBM','LightGBMXT',
        'XGBoost', 'LightGBM','LightGBMXT'
    ],
    'Accuracy': [0.8875 ,0.8625 ,0.8813 ,0.8563,0.8563,0.8688,0.8625,0.85,0.8625,0.88125,0.88125,0.8875],
    'Recall': [0.8875 ,0.8625 ,0.8813 ,0.8563,0.8563,0.8688,0.8625,0.85,0.8625,0.88125,0.88125,0.8875],
    'F1 Score': [0.8895 ,0.8651 ,0.8824 ,0.8605,0.8611,0.8718,0.8663,0.8532,0.8652,0.8828,0.8830,0.8874],
    'Precision': [0.8965 ,0.8724 ,0.8879 ,0.8701,0.8715,0.8795,0.8746,0.8612,0.8717,0.8901,0.8906,0.8907]
}

df = pd.DataFrame(data)

# 转换为适合 seaborn 的长格式
df_melted = df.melt(id_vars=['特征', '模型'], 
                    value_vars=['Accuracy', 'Recall', 'F1 Score', 'Precision'],
                    var_name='评估指标', value_name='得分')

# 计算同一评估指标下，每个特征的平均值
df_avg = df_melted.groupby(['特征', '评估指标'])['得分'].mean().reset_index()

# 设置风格
sns.set(style="whitegrid")

# 绘图
plt.figure(figsize=(16, 6))
chart = sns.barplot(
    x='评估指标', y='得分', hue='特征',
    data=df_avg, ci=None, palette='Set2'
)

# 添加数值标签
for container in chart.containers:
    chart.bar_label(container, fmt='%.3f', label_type='edge', fontsize=16, padding=2, fontproperties=font_en)

# 设置标题和标签（中文）
# plt.title('不同特征方法下的评估指标平均表现', fontsize=18, fontproperties=font_cn)
plt.xlabel('评估指标', fontsize=20, fontproperties=font_cn)
plt.ylabel('平均得分', fontsize=20, fontproperties=font_cn)
plt.ylim(0.845, 0.92)

# 设置图例字体和横向排列
# legend = plt.legend(prop=font_en, ncol=4, loc='upper right')

legend = plt.legend(prop=FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=16), ncol=4, loc='upper right')
legend.get_title().set_fontproperties(font_cn)

plt.xticks(fontproperties=font_en)
plt.yticks(fontproperties=font_en)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\4209235170.py:45: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   chart = sns.barplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=20)  # 中文宋体
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=20)   # Times New Roman

# 构造数据
data = {
    '特征': [
        'Key Gas Torch', 'Key Gas FastAI',
        'IEC Torch', 'IEC FastAI',
        'Roger Torch', 'Roger FastAI',
        'Duval Torch', 'Duval FastAI'
    ],
    '模型': [
        'NeuralNetTorch', 'NeuralNetFastAI',
        'NeuralNetTorch', 'NeuralNetFastAI',
        'NeuralNetTorch', 'NeuralNetFastAI',
        'NeuralNetTorch', 'NeuralNetFastAI'
    ],
    'Accuracy': [0.8438 ,0.8250 ,0.825,0.8125,0.79375,0.80625,0.88125,0.8],
    'Recall': [0.8438 ,0.8250 ,0.825,0.8125,0.79375,0.80625,0.88125,0.8],
    'F1 Score': [0.8474 ,0.8243 ,0.8217,0.8115,0.7851,0.8055,0.8824,0.7897],
    'Precision': [0.8592 ,0.8251 ,0.8269,0.8139,0.7939,0.8076,0.8934,0.7997]
}

df = pd.DataFrame(data)

# 转换为适合 seaborn 的长格式
df_melted = df.melt(id_vars=['特征', '模型'], 
                    value_vars=['Accuracy', 'Recall', 'F1 Score', 'Precision'],
                    var_name='评估指标', value_name='得分')

# 计算同一评估指标下，每个特征的平均值
df_avg = df_melted.groupby(['特征', '评估指标'])['得分'].mean().reset_index()

# 设置风格
sns.set(style="whitegrid")

# 绘图
plt.figure(figsize=(16, 6))
chart = sns.barplot(
    x='评估指标', y='得分', hue='特征',
    data=df_avg, ci=None, palette='Set2'
)

# 添加数值标签
for container in chart.containers:
    chart.bar_label(container, fmt='%.3f', label_type='edge', fontsize=16, padding=2, fontproperties=font_en)

# 设置标题和标签（中文）
# plt.title('不同特征方法下的评估指标平均表现', fontsize=18, fontproperties=font_cn)
plt.xlabel('评估指标', fontsize=20, fontproperties=font_cn)
plt.ylabel('平均得分', fontsize=20, fontproperties=font_cn)
plt.ylim(0.79, 0.93)

# 设置图例字体和横向排列
legend = plt.legend(prop=font_en, ncol=4, loc='upper right')
legend.get_title().set_fontproperties(font_cn)


plt.xticks(fontproperties=font_en)
plt.yticks(fontproperties=font_en)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\1827820337.py:45: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   chart = sns.barplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=20)  # 中文宋体
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=20)   # Times New Roman

# 构造数据
data = {
    '特征': [
        'Key Gas Dis', 'Key Gas Unif',
        'IEC Dis', 'IEC Unif',
        'Roger Dis', 'Roger Unif',
        'Duval Dis', 'Duval Unif'
    ],
    '模型': [
        'KNeighborsDis', 'KNeighborsUnif',
        'KNeighborsDis', 'KNeighborsUnif',
        'KNeighborsDis', 'KNeighborsUnif',
        'KNeighborsDis', 'KNeighborsUnif'
    ],
    'Accuracy': [0.8188 ,0.7500 ,0.8,0.7313,0.80625,0.73125,0.81875,0.75],
    'Recall': [0.8188 ,0.7500 ,0.8,0.7313,0.80625,0.73125,0.81875,0.75],
    'F1 Score': [0.8226 ,0.7480 ,0.803,0.7303,0.8083,0.7280,0.8226,0.7480],
    'Precision': [0.8341 ,0.7486 ,0.8109,0.7328,0.8154,0.7288,0.8341,0.7486]
}

df = pd.DataFrame(data)

# 转换为适合 seaborn 的长格式
df_melted = df.melt(id_vars=['特征', '模型'], 
                    value_vars=['Accuracy', 'Recall', 'F1 Score', 'Precision'],
                    var_name='评估指标', value_name='得分')

# 计算同一评估指标下，每个特征的平均值
df_avg = df_melted.groupby(['特征', '评估指标'])['得分'].mean().reset_index()

# 设置风格
sns.set(style="whitegrid")

# 绘图
plt.figure(figsize=(16, 6))
chart = sns.barplot(
    x='评估指标', y='得分', hue='特征',
    data=df_avg, ci=None, palette='Set2'
)

# 添加数值标签
for container in chart.containers:
    chart.bar_label(container, fmt='%.3f', label_type='edge', fontsize=16, padding=2, fontproperties=font_en)

# 设置标题和标签（中文）
# plt.title('不同特征方法下的评估指标平均表现', fontsize=18, fontproperties=font_cn)
plt.xlabel('评估指标', fontsize=20, fontproperties=font_cn)
plt.ylabel('平均得分', fontsize=20, fontproperties=font_cn)
plt.ylim(0.725, 0.87)

# 设置图例字体和横向排列
legend = plt.legend(prop=font_en, ncol=4, loc='upper right')
legend.get_title().set_fontproperties(font_cn)


plt.xticks(fontproperties=font_en)
plt.yticks(fontproperties=font_en)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\574017288.py:45: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   chart = sns.barplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=20)  # 中文宋体
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=20)   # Times New Roman

# 构造数据
data = {
    '特征': [
        'Key Gas',
        'IEC',
        'Roger',
        'Duval'
    ],
    '模型': [
        'SVM', 
        'SVM', 
        'SVM', 
        'SVM'
    ],
    'Accuracy': [0.7625,0.7625,0.7688,0.7688],
    'Recall': [0.7072,0.7072,0.7186,0.7194],
    'F1 Score': [0.7080,0.7101,0.7221,0.7118],
    'Precision': [0.7102,0.7150,0.7274,0.7141]
}

df = pd.DataFrame(data)

# 转换为适合 seaborn 的长格式
df_melted = df.melt(id_vars=['特征', '模型'], 
                    value_vars=['Accuracy', 'Recall', 'F1 Score', 'Precision'],
                    var_name='评估指标', value_name='得分')

# 计算同一评估指标下，每个特征的平均值
df_avg = df_melted.groupby(['特征', '评估指标'])['得分'].mean().reset_index()

# 设置风格
sns.set(style="whitegrid")

# 绘图
plt.figure(figsize=(16, 6))
chart = sns.barplot(
    x='评估指标', y='得分', hue='特征',
    data=df_avg, ci=None, palette='Set2'
)

# 添加数值标签
for container in chart.containers:
    chart.bar_label(container, fmt='%.3f', label_type='edge', fontsize=16, padding=2, fontproperties=font_en)

# 设置标题和标签（中文）
# plt.title('不同特征方法下的评估指标平均表现', fontsize=18, fontproperties=font_cn)
plt.xlabel('评估指标', fontsize=20, fontproperties=font_cn)
plt.ylabel('平均得分', fontsize=20, fontproperties=font_cn)
plt.ylim(0.70, 0.78)

# 设置图例字体和横向排列
legend = plt.legend(prop=font_en, ncol=4, loc='upper right')
legend.get_title().set_fontproperties(font_cn)


plt.xticks(fontproperties=font_en)
plt.yticks(fontproperties=font_en)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\11094\AppData\Local\Temp\ipykernel_24968\4027644794.py:45: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   chart = sns.barplot(

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=16)
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=16)

# 构造数据
data = {
    '特征': [
        'Key Gas'] * 9 + ['IEC'] * 9 + ['Roger'] * 9 + ['Duval'] * 9,
    '模型': [
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
    ],
    'Accuracy': [
        0.8875, 0.8875, 0.8875, 0.8938, 0.8875, 0.8625, 0.8813, 0.8438, 0.8250,
        0.8938, 0.8875, 0.8938, 0.8875, 0.8563, 0.8563, 0.8688, 0.8250, 0.8125,
        0.8750, 0.8813, 0.9000, 0.89375, 0.8625, 0.85, 0.8625, 0.79375, 0.80625,
        0.9000, 0.8875, 0.88125, 0.8875, 0.88125, 0.88125, 0.8875, 0.88125, 0.8000
    ]
}

df = pd.DataFrame(data)
df['方法'] = df['模型']+ ' ' + df['特征'] 

# 绘图
plt.figure(figsize=(18, 16))
bars = plt.bar(df['方法'], df['Accuracy'], color='skyblue')

# 添加数值标签
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.002, f'{height:.3f}', 
             ha='center', va='bottom', fontsize=12, fontproperties=font_en)

# 坐标轴设置
plt.xlabel('方法', fontsize=16, fontproperties=font_cn)
plt.ylabel('准确率', fontsize=16, fontproperties=font_cn)
plt.xticks(rotation=90, fontsize=12, fontproperties=font_en)
plt.yticks(fontsize=12, fontproperties=font_en)

# 不显示图例
plt.tight_layout()
plt.ylim(0.72, 0.92)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=16)
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=16)

# 构造数据
data = {
    '特征': ['Key Gas'] * 9 + ['IEC'] * 9 + ['Roger'] * 9 + ['Duval'] * 9,
    '模型': [
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
    ],
    'Accuracy': [
        0.8875, 0.8875, 0.8875, 0.8938, 0.8875, 0.8625, 0.8813, 0.8438, 0.8250,
        0.8938, 0.8875, 0.8938, 0.8875, 0.8563, 0.8563, 0.8688, 0.8250, 0.8125,
        0.8750, 0.8813, 0.9000, 0.89375, 0.8625, 0.85, 0.8625, 0.79375, 0.80625,
        0.9000, 0.8875, 0.88125, 0.8875, 0.88125, 0.88125, 0.8875, 0.88125, 0.8000
    ]
}

df = pd.DataFrame(data)
df['方法'] = df['模型'] + ' ' + df['特征']

# 分配颜色：为每个模型定义唯一颜色
unique_models = df['模型'].unique()
colors = plt.get_cmap('tab10').colors  # 使用 matplotlib 自带 colormap

# 构建模型到颜色的映射字典
model_color_map = {model: colors[i % len(colors)] for i, model in enumerate(unique_models)}
df['颜色'] = df['模型'].map(model_color_map)

# 绘图
plt.figure(figsize=(18, 16))
bars = plt.bar(df['方法'], df['Accuracy'], color=df['颜色'])

# 添加数值标签
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.002, f'{height:.3f}',
             ha='center', va='bottom', fontsize=12, fontproperties=font_en)

# 坐标轴设置
plt.xlabel('方法', fontsize=16, fontproperties=font_cn)
plt.ylabel('准确率', fontsize=16, fontproperties=font_cn)
plt.xticks(rotation=90, fontsize=12, fontproperties=font_en)
plt.yticks(fontsize=12, fontproperties=font_en)
plt.ylim(0.72, 0.92)

# 不显示图例
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib.font_manager import FontProperties

# 设置 seaborn 风格
sns.set(style="whitegrid")

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=16)
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=16)

# 构造数据
data = {
    '特征': ['Key Gas'] * 9 + ['IEC'] * 9 + ['Roger'] * 9 + ['Duval'] * 9,
    '模型': [
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', 'NeuralNetTorch', 'NeuralNetFastAI',
    ],
    'Accuracy': [
        0.8875, 0.8875, 0.8875, 0.8938, 0.8875, 0.8625, 0.8813, 0.8438, 0.8250,
        0.8938, 0.8875, 0.8938, 0.8875, 0.8563, 0.8563, 0.8688, 0.8250, 0.8125,
        0.8750, 0.8813, 0.9000, 0.89375, 0.8625, 0.85, 0.8625, 0.79375, 0.80625,
        0.9000, 0.8875, 0.88125, 0.8875, 0.88125, 0.88125, 0.8875, 0.88125, 0.8000
    ]
}

df = pd.DataFrame(data)
df['方法'] = df['模型'] + ' ' + df['特征']

# 分配颜色：为每个模型定义唯一颜色
unique_models = df['模型'].unique()
palette = sns.color_palette("tab10", n_colors=len(unique_models))
model_color_map = {model: palette[i % len(palette)] for i, model in enumerate(unique_models)}
df['颜色'] = df['模型'].map(model_color_map)

# 绘图
plt.figure(figsize=(18, 16))
bars = plt.bar(df['方法'], df['Accuracy'], color=df['颜色'])

# 添加数值标签
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.002, f'{height:.3f}',
             ha='center', va='bottom', fontsize=12, fontproperties=font_en)

# 坐标轴设置
plt.xlabel('方法', fontsize=16, fontproperties=font_cn)
plt.ylabel('准确率', fontsize=16, fontproperties=font_cn)
plt.xticks(rotation=90, fontsize=12, fontproperties=font_en)
plt.yticks(fontsize=12, fontproperties=font_en)
plt.ylim(0.72, 0.92)

# 不显示图例，紧凑布局
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=16)
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=16)

# 构造数据
data = {
    '特征': ['Key Gas'] * 7 + ['IEC'] * 7 + ['Roger'] * 7 + ['Duval'] * 7,
    '模型': [
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT',# 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
    ],
    'Accuracy': [
        0.8875, 0.8875, 0.8875, 0.8938, 0.8875, 0.8625, 0.8813, #0.8438, 0.8250,
        0.8938, 0.8875, 0.8938, 0.8875, 0.8563, 0.8563, 0.8688, #0.8250, 0.8125,
        0.8750, 0.8813, 0.9000, 0.89375, 0.8625, 0.85, 0.8625, #0.79375, 0.80625,
        0.9000, 0.8875, 0.88125, 0.8875, 0.88125, 0.88125, 0.8875, #0.88125, 0.8000
    ]
}

df = pd.DataFrame(data)
df['方法'] = df['模型'] + ' ' + df['特征']

# 自定义 9 个颜色（你提供的前 8 个 + 自定义新加的一个）
model_colors = [
    '#72b6a1',  # 1
    '#e99675',  # 2
    '#95a3c3',  # 3
    '#db96c0',  # 4
    '#b0cc5a',  # 5
    '#e2c148',  # 6
    '#dfc7a3',  # 7
    # '#bdbdbd',  # 8
    # '#97c9ba'   # 9 - 新补充的
]

# 映射模型到颜色
unique_models = [
    'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr',
    'XGBoost', 'LightGBM', 'LightGBMXT'#, 'NeuralNetTorch', 'NeuralNetFastAI'
]
model_color_map = dict(zip(unique_models, model_colors))
df['颜色'] = df['模型'].map(model_color_map)

# 设置风格
import seaborn as sns
sns.set(style="whitegrid")

# 绘图
plt.figure(figsize=(18, 16))
bars = plt.bar(df['方法'], df['Accuracy'], color=df['颜色'])

# 添加数值标签
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.3f}',
             ha='center', va='bottom', fontsize=14, fontproperties=font_en)

# 坐标轴设置
plt.xlabel('方法', fontsize=16, fontproperties=font_cn)
plt.ylabel('准确率', fontsize=16, fontproperties=font_cn)
plt.xticks(rotation=90, fontsize=12, fontproperties=font_en)
plt.yticks(fontsize=12, fontproperties=font_en)
plt.ylim(0.84, 0.905)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=16)
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=16)

# 构造数据
data = {
    '特征': ['Key Gas'] * 7 + ['IEC'] * 7 + ['Roger'] * 7 + ['Duval'] * 7,
    '模型': [
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT',# 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
    ],
    'Recall': [
        0.8904, 0.8901, 0.8883, 0.8947, 0.8895, 0.8651, 0.8824, #0.8438, 0.8250,
        0.8939, 0.8883, 0.8939, 0.8883, 0.8605, 0.8611, 0.8718, #0.8250, 0.8125,
        0.8790, 0.8835, 0.9004, 0.8938, 0.8663, 0.8532, 0.8652, #0.79375, 0.80625,
        0.9018, 0.8896, 0.8814, 0.8882, 0.8828, 0.8830, 0.8874, #0.88125, 0.8000
    ]
}

df = pd.DataFrame(data)
df['方法'] = df['模型'] + ' ' + df['特征']

# 自定义 9 个颜色（你提供的前 8 个 + 自定义新加的一个）
model_colors = [
    '#72b6a1',  # 1
    '#e99675',  # 2
    '#95a3c3',  # 3
    '#db96c0',  # 4
    '#b0cc5a',  # 5
    '#e2c148',  # 6
    '#dfc7a3',  # 7
    # '#bdbdbd',  # 8
    # '#97c9ba'   # 9 - 新补充的
]

# 映射模型到颜色
unique_models = [
    'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr',
    'XGBoost', 'LightGBM', 'LightGBMXT'#, 'NeuralNetTorch', 'NeuralNetFastAI'
]
model_color_map = dict(zip(unique_models, model_colors))
df['颜色'] = df['模型'].map(model_color_map)

# 设置风格
import seaborn as sns
sns.set(style="whitegrid")

# 绘图
plt.figure(figsize=(18, 16))
bars = plt.bar(df['方法'], df['Recall'], color=df['颜色'])

# 添加数值标签
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.3f}',
             ha='center', va='bottom', fontsize=14, fontproperties=font_en)

# 坐标轴设置
plt.xlabel('方法', fontsize=16, fontproperties=font_cn)
plt.ylabel('Recall', fontsize=16, fontproperties=font_en)
plt.xticks(rotation=90, fontsize=12, fontproperties=font_en)
plt.yticks(fontsize=12, fontproperties=font_en)
plt.ylim(0.85, 0.905)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=16)
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=16)

# 构造数据
data = {
    '特征': ['Key Gas'] * 7 + ['IEC'] * 7 + ['Roger'] * 7 + ['Duval'] * 7,
    '模型': [
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT',# 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
    ],
    'F1': [
        0.8904, 0.8901, 0.8883, 0.8947, 0.8895, 0.8651, 0.8824, #0.8438, 0.8250,
        0.8939, 0.8883, 0.8939, 0.8883, 0.8605, 0.8611, 0.8718, #0.8250, 0.8125,
        0.8790, 0.8835, 0.9004, 0.8938, 0.8663, 0.8532, 0.8652, #0.79375, 0.80625,
        0.9018, 0.8896, 0.8814, 0.8882, 0.8828, 0.8830, 0.8874, #0.88125, 0.8000
    ]
}

df = pd.DataFrame(data)
df['方法'] = df['模型'] + ' ' + df['特征']

# 自定义 9 个颜色（你提供的前 8 个 + 自定义新加的一个）
model_colors = [
    '#72b6a1',  # 1
    '#e99675',  # 2
    '#95a3c3',  # 3
    '#db96c0',  # 4
    '#b0cc5a',  # 5
    '#e2c148',  # 6
    '#dfc7a3',  # 7
    # '#bdbdbd',  # 8
    # '#97c9ba'   # 9 - 新补充的
]

# 映射模型到颜色
unique_models = [
    'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr',
    'XGBoost', 'LightGBM', 'LightGBMXT'#, 'NeuralNetTorch', 'NeuralNetFastAI'
]
model_color_map = dict(zip(unique_models, model_colors))
df['颜色'] = df['模型'].map(model_color_map)

# 设置风格
import seaborn as sns
sns.set(style="whitegrid")

# 绘图
plt.figure(figsize=(18, 16))
bars = plt.bar(df['方法'], df['F1'], color=df['颜色'])

# 添加数值标签
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.3f}',
             ha='center', va='bottom', fontsize=14, fontproperties=font_en)

# 坐标轴设置
plt.xlabel('方法', fontsize=16, fontproperties=font_cn)
plt.ylabel('F1', fontsize=16, fontproperties=font_en)
plt.xticks(rotation=90, fontsize=12, fontproperties=font_en)
plt.yticks(fontsize=12, fontproperties=font_en)
plt.ylim(0.85, 0.905)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.font_manager import FontProperties

# 设置字体
font_cn = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=16)
font_en = FontProperties(fname=r"C:\Windows\Fonts\times.ttf", size=16)

# 构造数据
data = {
    '特征': ['Key Gas'] * 7 + ['IEC'] * 7 + ['Roger'] * 7 + ['Duval'] * 7,
    '模型': [
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT',# 'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
        'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr', 'XGBoost', 'LightGBM', 'LightGBMXT', #'NeuralNetTorch', 'NeuralNetFastAI',
    ],
    'Precision': [
        0.8968, 0.8957, 0.8931, 0.8995, 0.8965, 0.8724, 0.8879, #0.8438, 0.8250,
        0.8988, 0.8931, 0.8988, 0.8931, 0.8701, 0.8715, 0.8795, #0.8250, 0.8125,
        0.8885, 0.8881, 0.9049, 0.8968, 0.8746, 0.8612, 0.8717, #0.79375, 0.80625,
        0.9066, 0.8963, 0.8897, 0.8946, 0.8901, 0.8906, 0.8907, #0.88125, 0.8000
    ]
}

df = pd.DataFrame(data)
df['方法'] = df['模型'] + ' ' + df['特征']

# 自定义 9 个颜色（你提供的前 8 个 + 自定义新加的一个）
model_colors = [
    '#72b6a1',  # 1
    '#e99675',  # 2
    '#95a3c3',  # 3
    '#db96c0',  # 4
    '#b0cc5a',  # 5
    '#e2c148',  # 6
    '#dfc7a3',  # 7
    # '#bdbdbd',  # 8
    # '#97c9ba'   # 9 - 新补充的
]

# 映射模型到颜色
unique_models = [
    'RandomForestGini', 'RandomForestEntr', 'ExtraTreesGini', 'ExtraTreesEntr',
    'XGBoost', 'LightGBM', 'LightGBMXT'#, 'NeuralNetTorch', 'NeuralNetFastAI'
]
model_color_map = dict(zip(unique_models, model_colors))
df['颜色'] = df['模型'].map(model_color_map)

# 设置风格
import seaborn as sns
sns.set(style="whitegrid")

# 绘图
plt.figure(figsize=(18, 16))
bars = plt.bar(df['方法'], df['Precision'], color=df['颜色'])

# 添加数值标签
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001, f'{height:.3f}',
             ha='center', va='bottom', fontsize=14, fontproperties=font_en)

# 坐标轴设置
plt.xlabel('方法', fontsize=16, fontproperties=font_cn)
plt.ylabel('Precision', fontsize=16, fontproperties=font_en)
plt.xticks(rotation=90, fontsize=12, fontproperties=font_en)
plt.yticks(fontsize=12, fontproperties=font_en)
plt.ylim(0.86, 0.91)

plt.tight_layout()
plt.show()
